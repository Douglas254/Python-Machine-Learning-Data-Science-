# %% [markdown]
# # Linestyle
# You can use the keyword argument `linestyle`, or shorter `ls`, to change the style of the plotted line:

# %%
# Example:
# Use a dotted line:

import matplotlib.pyplot as plt
import numpy as np

y_axis_points = np.array([2, 6, 0, 15])

plt.plot(y_axis_points, linestyle = 'dotted')
plt.show()

# %%
# using a dashed line
import matplotlib.pyplot as plt
import numpy as np

y_axis_points = np.array([2,7,3,5,9])

plt.plot(y_axis_points, linestyle = 'dashed')
plt.show()

# %% [markdown]
# # Shorter Syntax
# The line style can be written in a shorter syntax:
#
# `linestyle can be written as ls.`
#
# `dotted can be written as :.`
#
# `dashed can be written as --.`

# %% [markdown]
# # Line Color
# You can use the keyword argument `color` or the shorter `c` to set the color of the line
#
# Example:
#
# Set the line color to green:

# %%
import matplotlib.pyplot as plt
import numpy as np

y_axis_points = np.array([2,7,3,5,9])

plt.plot(y_axis_points, color='g')
plt.show()

# %% [markdown]
# # Line Width
# You can use the keyword argument `linewidth` or the shorter `lw` to change the width of the line.
#
# The value is a floating number, in points:

# %%
# Example
# Plot with a 10.5pt wide line:

import matplotlib.pyplot as plt
import numpy as np

y_axis_points = np.array([2,7,3,5,9])

plt.plot(y_axis_points, linewidth=10.5)
plt.show()

# %% [markdown]
# # Multiple Lines
# You can plot as many lines as you like by simply adding more `plt.plot()` functions:

# %%
import matplotlib.pyplot as plt
import numpy as np

y1_axis_points = np.array([2,7,3,5,9])
y2_axis_points = np.array([3,1,5,8,15])

plt.plot(y1_axis_points, c='g')
plt.plot(y2_axis_points, c='r')

plt.show()

# %% [markdown]
# <b>You can also plot many lines by adding the points for the x- and y-axis for each line in the same `plt.plot()` function.</b>
#
# Example:
#
# Draw two lines by specifiyng the x- and y-point values for both lines:

# %%
import matplotlib.pyplot as plt
import numpy as np

x1_axis_points = np.array([1,2,3,4,5])
y1_axis_points = np.array([2,7,3,5,9])
x2_axis_points = np.array([1,2,3,4,5])
y2_axis_points = np.array([3,1,5,8,15])


plt.plot(x1_axis_points, y1_axis_points, x2_axis_points, y2_axis_points)
plt.show()
