# %%
# importing pandas library
import pandas as pd

# %%
# reading the csv file
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# reading excel file 
df1 = pd.read_excel("data.xlsx")

# %%
# viewing the first few rows using the head function
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# PANDAS DATA FRAMES
#selecting a single column by name
df['Item_Type']
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %%
# selecting multiple columns by column names
df[['Item_Type','Item_Outlet_Sales']]
# Out:
#                   Item_Type  Item_Outlet_Sales
# 0                     Dairy          3735.1380
# 1               Soft Drinks           443.4228
# 2                      Meat          2097.2700
# 3     Fruits and Vegetables           732.3800
# 4                 Household           994.7052
# ...                     ...                ...
# 8518            Snack Foods          2778.3834
# 8519           Baking Goods           549.2850
# 8520     Health and Hygiene          1193.1136
# 8521            Snack Foods          1845.5976
# 8522            Soft Drinks           765.6700
#
# [8523 rows x 2 columns]

# %%
# selecting rows by their positions
# loc: label-based
# iloc: integer position-based
df.iloc[:3]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
# selecting columns by their positions
# [:, means selecting all the rows and :2] means selecting two columns
df.iloc[:,:2]
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [8523 rows x 2 columns]

# %%
# selecting column based on the condition
df[df['Outlet_Establishment_Year']==1999]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 10             FDY07       11.800          Low Fat         0.000000
# 12             FDX32       15.100          Regular         0.100014
# 17             FDP49        9.000          Regular         0.069196
# ...              ...          ...              ...              ...
# 8451           FDK21        7.905          Low Fat         0.010028
# 8467           FDV31        9.800               LF         0.000000
# 8470           FDW27        5.860          Regular         0.151088
# 8475           NCS17       18.600          Low Fat         0.080627
# 8479           FDL10        8.395          Low Fat         0.039554
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...
